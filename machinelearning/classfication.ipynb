# %% [markdown]
# # 分類
#
# 正解ラベルが離散値であり、あるデータがどのタスクに割り当てられるのかを予測するタスク
#
# # 腫瘍の良性・悪性判定タスク
#
# 腫瘍が良性か悪性かで２値分類問題として考える

# %%
# scikit-learnで提供されている腫瘍のデータをimport
from sklearn.datasets import load_breast_cancer

# %%
# データをロード
breast_cancer = load_breast_cancer()
X = breast_cancer.data # 特徴量
y = breast_cancer.target # 目的変数
feature_names = breast_cancer.feature_names # 特徴量名

# %%
# 読み込んだ特徴量名を確認（"mean"が平均、"error"が標準誤差、"worst"が値が大きい3つの細胞の平均値）
print(feature_names)
# Out:
# ['mean radius' 'mean texture' 'mean perimeter' 'mean area'
#  'mean smoothness' 'mean compactness' 'mean concavity'
#  'mean concave points' 'mean symmetry' 'mean fractal dimension'
#  'radius error' 'texture error' 'perimeter error' 'area error'
#  'smoothness error' 'compactness error' 'concavity error'
#  'concave points error' 'symmetry error' 'fractal dimension error'
#  'worst radius' 'worst texture' 'worst perimeter' 'worst area'
#  'worst smoothness' 'worst compactness' 'worst concavity'
#  'worst concave points' 'worst symmetry' 'worst fractal dimension']

# %%
# Xの全ての行と10列目までを取り出す
X = X[:, :10]
print(X)
# Out:
# [[1.799e+01 1.038e+01 1.228e+02 ... 1.471e-01 2.419e-01 7.871e-02]
#  [2.057e+01 1.777e+01 1.329e+02 ... 7.017e-02 1.812e-01 5.667e-02]
#  [1.969e+01 2.125e+01 1.300e+02 ... 1.279e-01 2.069e-01 5.999e-02]
#  ...
#  [1.660e+01 2.808e+01 1.083e+02 ... 5.302e-02 1.590e-01 5.648e-02]
#  [2.060e+01 2.933e+01 1.401e+02 ... 1.520e-01 2.397e-01 7.016e-02]
#  [7.760e+00 2.454e+01 4.792e+01 ... 0.000e+00 1.587e-01 5.884e-02]]

# %%
# 日本語の特徴量名
columns = ['半径', 'テクスチャ', '周囲の長さ', '面積', '滑らかさ', 'コンパクト性', 'へこみ', 'へこみの数', '対称性', 'フラクタル次元']

# %%
from pandas import DataFrame
# 表形式のデータ
df = DataFrame(data=X[:, :10], columns=columns)
df['目的変数'] = y

# 下から５行目を表示
df.tail()
# Out:
#         半径  テクスチャ   周囲の長さ      面積     滑らかさ   コンパクト性      へこみ    へこみの数     対称性  \
# 564  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390  0.13890  0.1726
# 565  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400  0.09791  0.1752
# 566  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251  0.05302  0.1590
# 567  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140  0.15200  0.2397
# 568   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000  0.00000  0.1587
#
#      フラクタル次元  目的変数
# 564  0.05623     0
# 565  0.05533     0
# 566  0.05648     0
# 567  0.07016     0
# 568  0.05884     1

# %%
# 統計値
df.describe()
# Out:
#                半径       テクスチャ       周囲の長さ           面積        滑らかさ  \
# count  569.000000  569.000000  569.000000   569.000000  569.000000
# mean    14.127292   19.289649   91.969033   654.889104    0.096360
# std      3.524049    4.301036   24.298981   351.914129    0.014064
# min      6.981000    9.710000   43.790000   143.500000    0.052630
# 25%     11.700000   16.170000   75.170000   420.300000    0.086370
# 50%     13.370000   18.840000   86.240000   551.100000    0.095870
# 75%     15.780000   21.800000  104.100000   782.700000    0.105300
# max     28.110000   39.280000  188.500000  2501.000000    0.163400
#
#            コンパクト性         へこみ       へこみの数         対称性     フラクタル次元        目的変数
# count  569.000000  569.000000  569.000000  569.000000  569.000000  569.000000
# mean     0.104341    0.088799    0.048919    0.181162    0.062798    0.627417
# std      0.052813    0.079720    0.038803    0.027414    0.007060    0.483918
# ...

# %% [markdown]
# 現状10次元のデータになっているため（10個の特徴量からなるため）、
# 平面上（２次元）にプロット（観測値などを点でグラフに描き入れること）できない
# 10個の特徴量から2個の特徴量を選んでそれぞれの組み合わせで平面にプロットしていく

# %%
from matplotlib import pyplot
pyplot.rcParams['font.family'] = 'IPAexGothic'
from pandas.plotting import scatter_matrix

# %%
# 悪性の腫瘍を赤色、良性の腫瘍を青色にする
colors = ['red' if v == 0 else 'blue' for v in y]

# 散布図の描画
axes = scatter_matrix(df[columns], figsize=(20, 20), diagonal='kde', c=colors)

# %% [markdown]
# データをプロットした図を`散布図`という
# 判定システムを作るとなると、簡単そうな半径、面積、周囲の長さの特徴量からシステムを作り、
# それをベースラインとして精度を上げるために地道に特徴量を追加するのがスタンダードなやり方
