# %% [markdown]
# # ロジスティック回帰
#
# 例えば、天気予報だと、晴れや雨という事象（クラスラベル）のみではなく、降水確率まであると便利
# この場合、パーセプトロンだと実現できない、ロジスティック回帰で予測はできる
#
# 活性化関数としてシグモイド関数を利用する

# %%
from IPython.display import Image
Image("./img/logistics_1.png")

# %% [markdown]
# 入力zが小さい時は０、大きい時は1に近づく
# このようなシグモイド関数の出力を確率として扱うのがロジスティック回帰

# %% [markdown]
# ## ロジスティック回帰の学習
#
# 適切な重みwを求める方針なので、基本的にはパーセプトロンとにてる
# 活性化関数がシグモイド関数になったので（パーセプトロンは単位関数）少し複雑になった
#
# ### 目的関数とコスト関数
#
# 目的関数は機械学習モデルが最適化したい関数
# コスト関数は機械学習モデルが学習によって最小化したい関数

# %% [markdown]
# ## 勾配降下法
#
# コスト関数を最小化するような重みwを求める方法
# 勾配に従って坂を下るように重みを更新し続ければいつかは最小値に達するという考え

# %% [markdown]
# ## ロジスティック回帰の実験
